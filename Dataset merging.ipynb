# %%
import pandas as pd

# %%
s17= pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\FootBall_Data\\Season 2017-2018.csv')

# %%
s17
# Out:
#     Div        Date        HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0  11/08/2017         Arsenal     Leicester     4     3   H     2     2
# 1    E0  12/08/2017        Brighton      Man City     0     2   A     0     0
# 2    E0  12/08/2017         Chelsea       Burnley     2     3   A     0     3
# 3    E0  12/08/2017  Crystal Palace  Huddersfield     0     3   A     0     2
# 4    E0  12/08/2017         Everton         Stoke     1     0   H     1     0
# ..   ..         ...             ...           ...   ...   ...  ..   ...   ...
# 375  E0  13/05/2018       Newcastle       Chelsea     3     0   H     1     0
# 376  E0  13/05/2018     Southampton      Man City     0     1   A     0     0
# 377  E0  13/05/2018         Swansea         Stoke     1     2   A     1     2
# 378  E0  13/05/2018       Tottenham     Leicester     5     4   H     1     2
# 379  E0  13/05/2018        West Ham       Everton     3     1   H     1     0
#
# ...

# %%
s17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 65 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Div       380 non-null    object
#  1   Date      380 non-null    object
#  2   HomeTeam  380 non-null    object
#  3   AwayTeam  380 non-null    object
#  4   FTHG      380 non-null    int64
#  5   FTAG      380 non-null    int64
#  6   FTR       380 non-null    object
#  7   HTHG      380 non-null    int64
#  8   HTAG      380 non-null    int64
#  9   HTR       380 non-null    object
#  10  Referee   380 non-null    object
#  11  HS        380 non-null    int64
#  12  AS        380 non-null    int64
#  13  HST       380 non-null    int64
#  14  AST       380 non-null    int64
#  15  HF        380 non-null    int64
#  16  AF        380 non-null    int64
#  17  HC        380 non-null    int64
#  18  AC        380 non-null    int64
#  19  HY        380 non-null    int64
# ...

# %%
s18= pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\FootBall_Data\\Season 2018-2019.csv')

# %%
s19= pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\FootBall_Data\\Season 2019-2020.csv')

# %%
s20= pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\FootBall_Data\\Season 2020-2021.csv')

# %%
s21= pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\FootBall_Data\\Season 2021-2022.csv')

# %%
df=pd.concat([s17,s18,s19,s20,s21], ignore_index=True)
seasons=[s17,s18,s19,s20,s21]
seasons
# Out:
# [    Div        Date        HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
#  0    E0  11/08/2017         Arsenal     Leicester     4     3   H     2     2
#  1    E0  12/08/2017        Brighton      Man City     0     2   A     0     0
#  2    E0  12/08/2017         Chelsea       Burnley     2     3   A     0     3
#  3    E0  12/08/2017  Crystal Palace  Huddersfield     0     3   A     0     2
#  4    E0  12/08/2017         Everton         Stoke     1     0   H     1     0
#  ..   ..         ...             ...           ...   ...   ...  ..   ...   ...
#  375  E0  13/05/2018       Newcastle       Chelsea     3     0   H     1     0
#  376  E0  13/05/2018     Southampton      Man City     0     1   A     0     0
#  377  E0  13/05/2018         Swansea         Stoke     1     2   A     1     2
#  378  E0  13/05/2018       Tottenham     Leicester     5     4   H     1     2
#  379  E0  13/05/2018        West Ham       Everton     3     1   H     1     0
#
# ...

# %%
df
# Out:
#      Div        Date        HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     E0  11/08/2017         Arsenal     Leicester     4     3   H     2
# 1     E0  12/08/2017        Brighton      Man City     0     2   A     0
# 2     E0  12/08/2017         Chelsea       Burnley     2     3   A     0
# 3     E0  12/08/2017  Crystal Palace  Huddersfield     0     3   A     0
# 4     E0  12/08/2017         Everton         Stoke     1     0   H     1
# ...   ..         ...             ...           ...   ...   ...  ..   ...
# 1895  E0  22/05/2022  Crystal Palace    Man United     1     0   H     1
# 1896  E0  22/05/2022       Leicester   Southampton     4     1   H     0
# 1897  E0  22/05/2022       Liverpool        Wolves     3     1   H     1
# 1898  E0  22/05/2022        Man City   Aston Villa     3     2   H     0
# 1899  E0  22/05/2022         Norwich     Tottenham     0     5   A     0
#
#       HTAG HTR  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# ...

# %%
df.shape
# Out:
# (1900, 127)

# %%
df.to_csv('file_name.csv', index=False)

# %%
fdf=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\file_name.csv')

# %% [markdown]
# All Seasons Match Statistics Data

# %%
fdf
# Out:
#      Div        Date        HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     E0  11/08/2017         Arsenal     Leicester     4     3   H     2
# 1     E0  12/08/2017        Brighton      Man City     0     2   A     0
# 2     E0  12/08/2017         Chelsea       Burnley     2     3   A     0
# 3     E0  12/08/2017  Crystal Palace  Huddersfield     0     3   A     0
# 4     E0  12/08/2017         Everton         Stoke     1     0   H     1
# ...   ..         ...             ...           ...   ...   ...  ..   ...
# 1895  E0  22/05/2022  Crystal Palace    Man United     1     0   H     1
# 1896  E0  22/05/2022       Leicester   Southampton     4     1   H     0
# 1897  E0  22/05/2022       Liverpool        Wolves     3     1   H     1
# 1898  E0  22/05/2022        Man City   Aston Villa     3     2   H     0
# 1899  E0  22/05/2022         Norwich     Tottenham     0     5   A     0
#
#       HTAG HTR  ...    PSA    WHH  WHD    WHA    VCH   VCD    VCA   PSCH  \
# ...

# %% [markdown]
# Reading All Stadium Weather Data

# %%
sdf=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Arsenal.csv')

# %%
sdf
# Out:
#       YEAR  MO  DY    T2M  T2M_RANGE  T2M_MIN  T2M_MAX  QV2M  PRECTOTCORR  \
# 0     2017   1   1   5.05       5.23     2.54     7.77  5.31         9.54
# 1     2017   1   2   0.94       6.55    -2.17     4.39  3.85         0.14
# 2     2017   1   3   1.05       6.57    -1.96     4.61  3.78         0.13
# 3     2017   1   4   2.87       8.17    -1.67     6.51  4.27         0.14
# 4     2017   1   5   0.46       6.16    -1.82     4.35  3.72         0.06
# ...    ...  ..  ..    ...        ...      ...      ...   ...          ...
# 1972  2022   5  27  13.63       9.41     8.73    18.15  6.96         0.07
# 1973  2022   5  28  11.94       9.38     7.34    16.72  6.47         0.51
# 1974  2022   5  29   9.85       8.91     4.97    13.88  5.92         0.91
# 1975  2022   5  30  10.51       8.98     5.26    14.24  6.10         2.09
# 1976  2022   5  31  11.07       7.55     7.16    14.73  6.77         3.46
#
#           PS  WS10M  WS10M_MAX  WS10M_RANGE  WS10M_MIN   WD10M        Date  \
# ...

# %%
sdf.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s2df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Aston_Villa.csv')

# %%
s3df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Bournemouth.csv')

# %%
s4df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Brentford.csv')

# %%
s5df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Brighton.csv')

# %%
s6df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Burnely.csv')

# %%
s7df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Cardiff.csv')

# %%
s8df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Chelsea.csv')

# %%
s9df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Crystal Palace.csv')

# %%
s10df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Everton.csv')

# %%
s11df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Fulham.csv')

# %%
s12df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Huddersfield.csv')

# %%
s13df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Leeds.csv')

# %%
s14df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Leicester.csv')

# %%
s15df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Liverpool.csv')

# %%
s16df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Man City.csv')

# %%
s17df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Man United.csv')

# %%
s18df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Newcastle.csv')

# %%
s19df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Norwich.csv')

# %%
s20df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Sheffield United.csv')

# %%
s21df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Southampton.csv')

# %%
s22df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Stoke.csv')

# %%
s23df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Swansea.csv')

# %%
s24df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Tottenham.csv')

# %%
s25df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Watford.csv')

# %%
s26df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_West Brom.csv')

# %%
s27df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_West Ham.csv')

# %%
s28df=pd.read_csv('C:\\Users\\Aditya Likhar\\OneDrive\\Desktop\\Jupyter Notebook\\Dataset\\StadiumData_NASA\\POWER_Point_Daily_20170101_20220531_LST_Wolves.csv')

# %%
newsdf=pd.concat([sdf,s2df,s3df,s4df,s5df,s6df,s7df,s8df,s9df,s10df,s11df,s12df,s13df,s14df,s15df,s16df,s17df,s18df,s19df,s20df,s21df,s22df,s23df,s24df,s25df,s26df,s27df,s28df], ignore_index=True)

# %%
s5df
# Out:
#       YEAR  MO  DY    T2M  T2M_RANGE  T2M_MAX  T2M_MIN  QV2M  PRECTOTCORR  \
# 0     2017   1   1   6.55       5.39     8.90     3.51  5.68         9.31
# 1     2017   1   2   2.62       5.94     5.39    -0.55  4.21         0.80
# 2     2017   1   3   2.12       6.03     5.37    -0.66  4.15         0.06
# 3     2017   1   4   3.74       7.64     7.38    -0.27  4.58         0.14
# 4     2017   1   5   1.52       5.09     4.55    -0.54  3.97         0.06
# ...    ...  ..  ..    ...        ...      ...      ...   ...          ...
# 1972  2022   5  27  14.20       7.48    17.65    10.17  7.57         0.06
# 1973  2022   5  28  12.37       8.31    16.65     8.34  6.77         0.32
# 1974  2022   5  29  10.79       7.58    14.11     6.53  6.16         0.62
# 1975  2022   5  30  11.07       7.20    13.98     6.77  6.29         0.41
# 1976  2022   5  31  11.97       6.30    14.71     8.41  7.02         2.68
#
#           PS  WS10M  WS10M_MAX  WS10M_MIN  WS10M_RANGE   WD10M        Date  \
# ...

# %% [markdown]
# Renaming Stadium to Hometeam For merging weather data with Match Statistics Data:

# %%
s2df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)
s3df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)
s4df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)
s5df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s6df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s7df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s8df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s9df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s10df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s11df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s12df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s13df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s14df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s15df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s16df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s17df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s18df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s19df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s20df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s21df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s22df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s23df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s24df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s25df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s26df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s27df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %%
s28df.rename(columns={"Stadium": "HomeTeam"}, inplace=True)

# %% [markdown]
# All Stadium 5 years Weather Data

# %%
fwdf=pd.concat([sdf,s2df,s3df,s4df,s5df,s6df,s7df,s8df,s9df,s10df,s11df,s12df,s13df,s14df,s15df,s16df,s17df,s18df,s19df,s20df,s21df,s22df,s23df,s24df,s25df,s26df,s27df,s28df], ignore_index=True)

# %%
fwdf
# Out:
#          YEAR  MO  DY    T2M  T2M_RANGE  T2M_MIN  T2M_MAX  QV2M  PRECTOTCORR  \
# 0      2017.0   1   1   5.05       5.23     2.54     7.77  5.31         9.54
# 1      2017.0   1   2   0.94       6.55    -2.17     4.39  3.85         0.14
# 2      2017.0   1   3   1.05       6.57    -1.96     4.61  3.78         0.13
# 3      2017.0   1   4   2.87       8.17    -1.67     6.51  4.27         0.14
# 4      2017.0   1   5   0.46       6.16    -1.82     4.35  3.72         0.06
# ...       ...  ..  ..    ...        ...      ...      ...   ...          ...
# 55351  2022.0   5  27  11.68       9.72     6.73    16.45  6.29         0.01
# 55352  2022.0   5  28  11.66      11.16     5.82    16.98  6.41         0.11
# 55353  2022.0   5  29   9.94       6.19     7.19    13.37  6.10         1.43
# 55354  2022.0   5  30  10.31       7.68     6.18    13.85  6.35         1.95
# 55355  2022.0   5  31   9.76       6.66     6.57    13.23  6.41         3.76
#
# ...

# %%
fdf
# Out:
#      Div        Date        HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     E0  11/08/2017         Arsenal     Leicester     4     3   H     2
# 1     E0  12/08/2017        Brighton      Man City     0     2   A     0
# 2     E0  12/08/2017         Chelsea       Burnley     2     3   A     0
# 3     E0  12/08/2017  Crystal Palace  Huddersfield     0     3   A     0
# 4     E0  12/08/2017         Everton         Stoke     1     0   H     1
# ...   ..         ...             ...           ...   ...   ...  ..   ...
# 1895  E0  22/05/2022  Crystal Palace    Man United     1     0   H     1
# 1896  E0  22/05/2022       Leicester   Southampton     4     1   H     0
# 1897  E0  22/05/2022       Liverpool        Wolves     3     1   H     1
# 1898  E0  22/05/2022        Man City   Aston Villa     3     2   H     0
# 1899  E0  22/05/2022         Norwich     Tottenham     0     5   A     0
#
#       HTAG HTR  ...    WHH  WHD    WHA    VCH   VCD    VCA   PSCH  PSCD  \
# ...

# %% [markdown]
# Manually Removing Columns 'S' from fdf and Unnamed:44 from Excel Files

# %%
wfdf=pd.read_csv('C:\\Users\\Aditya Likhar\\fwdf.csv')

# %%
finaldf=pd.merge(fdf,wfdf, on=['Date','HomeTeam'],how='inner')

# %%
finaldf
# Out:
#      Div        Date        HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     E0  11/08/2017         Arsenal     Leicester     4     3   H     2
# 1     E0  12/08/2017        Brighton      Man City     0     2   A     0
# 2     E0  12/08/2017         Chelsea       Burnley     2     3   A     0
# 3     E0  12/08/2017  Crystal Palace  Huddersfield     0     3   A     0
# 4     E0  12/08/2017         Everton         Stoke     1     0   H     1
# ...   ..         ...             ...           ...   ...   ...  ..   ...
# 1895  E0  22/05/2022  Crystal Palace    Man United     1     0   H     1
# 1896  E0  22/05/2022       Leicester   Southampton     4     1   H     0
# 1897  E0  22/05/2022       Liverpool        Wolves     3     1   H     1
# 1898  E0  22/05/2022        Man City   Aston Villa     3     2   H     0
# 1899  E0  22/05/2022         Norwich     Tottenham     0     5   A     0
#
#       HTAG HTR  ... T2M_MIN  T2M_MAX   QV2M  PRECTOTCORR      PS  WS10M  \
# ...

# %%
finaldf.to_csv('finaldf.csv', index=False)
